# %% [markdown]
# # CS237: Homework 1
# - Due Date: July 23rd: Midnight

# %%
# CS 237: Lab 2

# Jupyter notebook specific 
from IPython.display import Image
from IPython.core.display import HTML 
from IPython.display import display_html
from IPython.display import display
from IPython.display import Math
from IPython.display import Latex
from IPython.display import HTML

# General useful imports
import numpy as np
from numpy import arange,linspace
import matplotlib.pyplot as plt  
from numpy.random import seed, randint, random, choice, shuffle
from collections import Counter
import pandas as pd

# To ensure that the plots are embeded in the notebook
# %matplotlib inline

# %% [markdown]
# ## Analytical Problems Introduction
#
#
#
#
# ### Note on format of numeric answers.
#
#
# The overall principle in writing your answers is to *make the problem easy to grade*! No one benefits from your
# work if they can not understand where the answer is or what value is actually being represented.
#
# There is no need to use Python to do the calculations or formatting for the analytical problems, although
# sometimes it is helpful to check your calculations.  You can insert a Code cell temporarily somewhere
# and type in the expression and cut and paste your answer into the Markdown cell with your solution.
#
# Here are the guidelines you should follow for the remainder of the course:
#
# - Quantitative answers must be given as small fractions, or in decimal. Small fractions are fine, as long as they are reduced (no common factors between the numerator and denominator) and not too complicated.  So 1/2, 3/8, and 5/32 are fine, but 1215/1944 (= 3/8) is not.
#
# - Quantitative answers in decimal should be given to 4 significant digits, unless very small, in which case you should give in scientific notation to 4 significant digits (if possible). We're flexible, but don't give an answer 20 digits long!
#
# - Whenever possible, show your answer in Latex (we'll do more on this later) inside a box, by enclosing it in the syntax:
#
#              $\boxed{  your answer   }$
#
# for example,
#
#             Here is pi:  $\boxed{3.1416}$.
#
# Here is pi:  $\boxed{3.1416}$.
#
# In the next text box are some useful `numpy` functions if you want to use them (not required as long as
# you follow the guidelines above).

# %%
# If you want to round something to 4 digits, you can use the 
# function np.around( floating-point number, number-of-significant-digits ):

print('Here is the number pi:', np.pi)
print('Here is the number pi rounded to 4 digits:', np.around(np.pi,4) )
print()

# using np.around
print(np.around(np.pi,4))           # this is perfect
print(np.around(np.pi/1000,4))      # this is ok
print(np.around(np.pi/100000,4))    # NOT OK,  this returns an inaccurate and unhelpful 0.0
print()

# using np.format_float_scientific(x,precision=4)

print( np.format_float_scientific(np.pi/1000,precision=4) )
print( np.format_float_scientific(np.pi/1000000,precision=4) )
# Out:
# Here is the number pi: 3.141592653589793
# Here is the number pi rounded to 4 digits: 3.1416
#
# 3.1416
# 0.0031
# 0.0
#
# 3.1416e-03
# 3.1416e-06

# %%
# Simmulation: Monty Hall 
Image('https://www.smbc-comics.com/comics/1483372014-20170102.png')

# %% [markdown]
# # Review Problem :
# A **fair** six sided die is rolled once. Write down the probability space and the probability function. I.e., the probability of each outcome
#
#
#
# **solution**

# %%
print("*" * 100)
# Out:
# ****************************************************************************************************

# %% [markdown]
# ### Problem 1
#
# Suppose you roll a single die $n$ times, $n>0$. Give the following probabilities in terms of $n$:
#
# (A)  The number 4 is observed all $n$ times;
#
# (B)  You *never* see the number 4 in any of the $n$ rolls;
#
# (C)  Each of the $n$ rolls shows an even number;
#
# (D)  The $n$ rolls alternate even and odd numbers, starting with even (for example:  2  5  4  1  6 5 ....);
#
# (E)  In the $n$ rolls, each of the numbers 1 and 6 are observed at least once.
#
# Hint for (E): Use the Inverse Method!

# %% [markdown]
# **Solution:**

# %%
print("*" * 100)
# Out:
# ****************************************************************************************************

# %% [markdown]
# ## Problem 2
#
# Suppose you roll two fair dice and count the number of dots showing. What is the probability of a sum of 5 if
#
# (A) the second roll is not 3?
#
# (B) they land on different numbers?

# %% [markdown]
# <b>Solution:</b>

# %%
print("*" * 100)
# Out:
# ****************************************************************************************************

# %% [markdown]
# ## Problem 3: [Biased dice]
# - A six-sided die is biased in a way that each even face is twice as likely as each odd face.
# - All even faces are equally likely, as are all odd faces.
# - Namely, let $A=\{2,4,6\}$ and $B=\{1,3,5\}$. then
#     - $\forall a\in A, Pr(\{a \}= c$ for some constant $c$
#     - $\forall b\in B, Pr(\{b \}= d$ for some constant $d$
#     - $c = 2  \times d$
#
# Describe the probability space for a single roll of this die. That is, write down the sample space and the probability function.
#
#
#
# Find the probability that the outcome is less than $4$.

# %% [markdown]
# **Solution**

# %%
print("*" * 100)
# Out:
# ****************************************************************************************************

# %% [markdown]
# ## Problem 4: [Biased coins]
# A coin is biased in such a way that it comes up heads with probability $p$, where $p  \in (0, 1) = \{x\in \mathbb{R} | 0<x<1 \}$.
# - Suppose we toss the coin $n$ times.
# - Let $A$ be the event that we observe exactly $k\leq n$ heads
#
#
# What is the probability of $A$?  Use the four step method.  That is:
# - Write down the Sample Space and find its cardinality
# - Write down the event of Interest ($A$)
# - Find the probability of outcomes (In this case, it is NOT equiprobable for all elements $\omega \in \Omega$ but there are groups within the set that have the same probablity!)
# - Hint: every string with exactly $k$ heads is equally likely. (Why?)
# - Hint: When trying to find the cardinality of $A$,  We are therefore interested in all bitstrings of weight $k$  of length $n$

# %% [markdown]
# **Solution**

# %%
print("*" * 100)
# Out:
# ****************************************************************************************************

# %% [markdown]
# ## Problem 5: [Monte Carlo Simulation]
#
# In this problem, you will simulate the random process described above. In particular you will build a function that takes as input
# - `n`, the number of coins
# - `p` the probability of getting a heads
# - `k` the number of heads.
# - `N` the number of times to repeat the experiment .
#
#
# - For one trial, it your code should generate $n$ uniform numbers in $[0,1]$.
# - Then check if each element is smaller than $p$. If so, this is a heads.
# - Count the number of heads  and check if this number is equal to $k$. If so, update a counter by 1.
# - At the end, it should return the number of times there were exactly $k$ heads and divide this by the number of trials `N`
#
#
#
# Hints:
# - You should simulate a $p$ biased coin using numpys function  `random`
# - Look at the code below, determine what exactly is is doing, and how you can adapt it to simulate the random process described above.

# %%
# Example of flipping a .75 biased coin 
p = .75

# number of coin flips 1000
n = 10
# Number of heads 
k = 5

#### Simmulate flipping a coin n times
# Start with uniform draws
trials  = random(n)
# This is just a bunch of random numbers between 0 and 1
print(trials)
# But we can view these as coinflips as follows: If the coin lands in the interval [0,p) then this is heads
# if it lands in [p,1] then it is tails 
# We can simply use numpy to broadcas the bounds check 
# Here, if the result is True, this is heads. Else, False
coin_outcomes = trials < p

# Count the number of heads in the outcome of coins 
# Since a heads is a 1,  and a tails is a 0, we can simply add all the elements in the coin outcomes 
number_heads = sum(coin_outcomes)
print("There were ", number_heads , " heads observed")
outcome = int(number_heads) == k
print(outcome)
# Out:
# [0.86102386 0.69907196 0.99003471 0.97726462 0.76026151 0.37886258
#  0.09180559 0.90131115 0.13977353 0.62301958]
# There were  5  heads observed
# True

# %%
def simmulate(n,p,k,N=10000):
    # Counter for the number of times the simualted string contained k heads
    c = 0
    # while we can broadcast the entire simulation, we should break it into batches
    for i in range(N):
        
        ##########################################
        ############ Your Code Here ##############
        # ≈ 3 lines of code 
        # Start with uniform draws
        raise(NotImplementedError)
        trials  = None
        # Convert  floats to outcomes (heads/tails)
        coin_outcomes = None
        # if condition is met, this will be 1 (True) and 0 otherwise (false)
        c += None
    return c/N
simmulate(10,.5,5)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-9-8afb2cedb6e1> in <module>
#      16         c += None
#      17     return c/N
# ---> 18 simmulate(10,.5,5)
#
# <ipython-input-9-8afb2cedb6e1> in simmulate(n, p, k, N)
#       9         # ≈ 3 lines of code
#      10         # Start with uniform draws
# ---> 11         raise(NotImplementedError)
#      12         trials  = None
#      13         # Convert  floats to outcomes (heads/tails)
#
# NotImplementedError:

# %% [markdown]
# # Problem 6 [Monte Carlo Simulation]
# Now lets estimate the distribution as a whole for each value of $k$.

# %%
# Super Slow way to way to plot the probability function  for k=0,1,...,n
# Can you tnink about how you can speed it up?
p=.5
n=10
x = [i for i in range(0,n+1)]
pr_x =[ simmulate(n,p,i) for i in x] 
plt.bar(x,pr_x)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-10-c89e45163e2a> in <module>
#       4 n=10
#       5 x = [i for i in range(0,n+1)]
# ----> 6 pr_x =[ simmulate(n,p,i) for i in x]
#       7 plt.bar(x,pr_x)
#
# <ipython-input-10-c89e45163e2a> in <listcomp>(.0)
#       4 n=10
#       5 x = [i for i in range(0,n+1)]
# ----> 6 pr_x =[ simmulate(n,p,i) for i in x]
#       7 plt.bar(x,pr_x)
#
# <ipython-input-9-8afb2cedb6e1> in simmulate(n, p, k, N)
#       9         # ≈ 3 lines of code
#      10         # Start with uniform draws
# ---> 11         raise(NotImplementedError)
#      12         trials  = None
#      13         # Convert  floats to outcomes (heads/tails)
#
# NotImplementedError:

# %%
def simulate_distribution(n, p, N=10000, non_zero = True):
    raise(NotImplementedError)

# %%
n, p = 100, .9
simulated_dist = simulate_distribution(n,p)
x = sorted([i for i in simulated_dist])
Pr_x = [simulated_dist[i] for i in x]
plt.bar(x, Pr_x)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-12-cbbf80c2139c> in <module>
#       1 n, p = 100, .9
# ----> 2 simulated_dist = simulate_distribution(n,p)
#       3 x = sorted([i for i in simulated_dist])
#       4 Pr_x = [simulated_dist[i] for i in x]
#       5 plt.bar(x, Pr_x)
#
# <ipython-input-11-25f75cf43680> in simulate_distribution(n, p, N, non_zero)
#       1 def simulate_distribution(n, p, N=10000, non_zero = True):
# ----> 2     raise(NotImplementedError)
#       3
#
# NotImplementedError:

# %%
print("*" * 100)
# Out:
# ****************************************************************************************************

# %% [markdown]
# **Solution**

# %%
print("*" * 100)
# Out:
# ****************************************************************************************************

# %% [markdown]
# # Problem 7
#  - We will use the randint function from the numpy.random library to simulate selecting a door randomly where each selection is equiprobable (such a choice is usually phrased as "uniformly at random").
#  - You may assume that for $n\in\mathbb{N}, n\geq 3$ doors, their numbers are $0,1,\ldots, n-1$
#  - Finish the stub for the code that initializes the game.
#  - This function should return a pair <code>(doors,winning_door)</code> where
# - doors is a 1D array of length <code>number_of_doors</code>, where exactly one of the elements is a 1 (the winning door), and the rest are 0 (the losing doors)
# - **winning_door is the index of the winning door **
#
# For example, if the array is [0,0,1], then the winning door is at index 2, while the losing doors are at 0,1, and the function would return ([0,0,1],2)

# %%
# Solution
def initialize_game(number_doors):
    raise(NotImplementedError)

# test
seed(42)
print( initialize_game(3) )
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-15-8e28c547a1bd> in <module>
#       5 # test
#       6 seed(42)
# ----> 7 print( initialize_game(3) )
#
# <ipython-input-15-8e28c547a1bd> in initialize_game(number_doors)
#       1 # Solution
#       2 def initialize_game(number_doors):
# ----> 3     raise(NotImplementedError)
#       4
#       5 # test
#
# NotImplementedError:

# %%
print("*" * 100)
# Out:
# ****************************************************************************************************

# %% [markdown]
# # Problem 8
# After the game is initialized (problem 1), the player will choose a door (this will be done in problem 4). Next, the host will open one or more doors, which we will simulate in this problem.  You must write a function <code>open_doors</code> which takes
#
#  - doors: the list generated from <code>initialize_game</code>
#  - ignore_doors: a list of doors (indices into the doors array) to exclude (i.e., the door selected by the player, and the winning door) and
#  - num_doors_to_open
#
# You must randomly generate a list of doors (opened_doors) that the host opens; these must be chosen from doors that are NOT in the list ignore_doors. The function returns a pair <code>(opened_doors, remaining_doors)</code>, where
#  - opened_doors is an array containing the indices of all doors opened.
#  - remaining_doors is an array of possible doors that were not in fact opened.
#
# Basically, the game enters this function with doors separated into doors that can not be opened by the host, and doors that the host can possibly open; the game leaves this function with a partition into three subsets: doors which must be ignored, doors randomly opened by the host, and all others. This last group is the set of doors that the player could switch to.
#
# **HINT** If there are only 3 doors to start, the function should be deterministic for a fixed array. In particular, for a fixed input, it will return the same output. Note that for Games with $N>3$, this is **not** true.
#
# - To assist you, we give you the <code> seed </code> function from numpy.random.
# - We will discuss this in a later lab, but the source randomness we use from numpy is *psuedorandom*. In particular, it is a *deterministic function* that only looks random if you don't know the *seed*.  Setting the seed to a specific value allows you to reproduce results, and will be used to grade your assignment.
#
# - We also recommend you use the <code> choice </code> function from numpy.random. See the example below. Suppose Kai is at a music festival, and most of his favorite bands are playing at the same time. Since he can only see one, he decides to randomly and uniformly select which band to go see. To acomplish this, he implements the following function below:
#     - For more on this <code> choice </code>, please execute <code> help(choice) </code>

# %%
# HINT: use the choice function from the reading!
# Example: try changing size , which is another way of specifying the length of a 1D array
# Try changing the seed

def pickBand(SEED =None):
    # If no seed is given, it will randomly generate one
    if SEED:
        seed(SEED) # set the seed to 42
    bands = ['Warpaint','STRFKR','Of Montreal', 'Grizzly Bear', 'Glass Animals', 'Tame Impala', 'Arctic Monkeys']
    return choice(bands, replace=False, size=2)
pickBand(SEED=42)
# Out:
# array(['Warpaint', 'STRFKR'], dtype='<U14')

# %%
# Solution
def open_doors(lst, selected , winning, n_doors_to_open ):
    """@Params:
    lst: The Door array 
    selected: Index of the door selected by the player
    winning: Index of the winning door
    n_doors_to_open: Number of doors the host will open
    """
    raise(NotImplementedError)
open_doors([0,0,1], 0,3,1), open_doors([1,0,0], 0,3,1)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-18-f34e2318136a> in <module>
#       8     """
#       9     raise(NotImplementedError)
# ---> 10 open_doors([0,0,1], 0,3,1), open_doors([1,0,0], 0,3,1)
#
# <ipython-input-18-f34e2318136a> in open_doors(lst, selected, winning, n_doors_to_open)
#       7     n_doors_to_open: Number of doors the host will open
#       8     """
# ----> 9     raise(NotImplementedError)
#      10 open_doors([0,0,1], 0,3,1), open_doors([1,0,0], 0,3,1)
#
# NotImplementedError:

# %%
print("*" * 100)
# Out:
# ****************************************************************************************************

# %% [markdown]
# # Problem 9
# Now that the game has been initialized, and the host has opened a door, complete the code stub below.
#
# The function new_door_choice should take as input:
#     - swap_behavior: the strategy the player uses encoded as an integer:
#         - Always trade (0): the player will trade no matter what, and randomly select a remaining door.
#         - Never trade (1): the player will always keep their initial choice.
#         - Randomly trade (2): the player flips a fair coin:
#             - if heads, he trades his door;
#             - if tails, he keeps his current choice.
#     - current_door: the door currently selected by the player, and
#     - rem_doors: a list of the doors the player can choose from if he decides to trade.
#
# The function should return the index at which the newly selected door is located.

# %%
# Solution
def new_door_choice(swap_behavior, current_door, rem_doors):
    raise(NotImplementedError)

# %%
print("*" * 100)
# Out:
# ****************************************************************************************************

# %% [markdown]
# # Problem 10: Putting it all together
# - Implement the function below to simulate playing 1 round of the Monty Hall game.
# - It should first initialize the doors.
# - Then select the players choice
# - The host will then open one or more doors
# - Finally, the player either keeps his door or trades
# - The function should return a boolean value:
#     - True if the player won the prize
#     - False if he doesn't

# %%
# Solution
def game( swap_behavior = 0,   num_doors=3, num_doors_to_open=1):
    raise(NotImplementedError)
    
Counter([game(swap_behavior=1) for i in range(1000)])
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-22-380137514962> in <module>
#       3     raise(NotImplementedError)
#       4
# ----> 5 Counter([game(swap_behavior=1) for i in range(1000)])
#
# <ipython-input-22-380137514962> in <listcomp>(.0)
#       3     raise(NotImplementedError)
#       4
# ----> 5 Counter([game(swap_behavior=1) for i in range(1000)])
#
# <ipython-input-22-380137514962> in game(swap_behavior, num_doors, num_doors_to_open)
#       1 # Solution
#       2 def game( swap_behavior = 0,   num_doors=3, num_doors_to_open=1):
# ----> 3     raise(NotImplementedError)
#       4
#       5 Counter([game(swap_behavior=1) for i in range(1000)])
#
# NotImplementedError:

# %%
print("*" * 100)
# Out:
# ****************************************************************************************************

# %% [markdown]
# # Problem 11
# - Simulate playing the game 10,000 times for each strategy with 3 doors, and 1 opened door.
# - Display a histogram to determine which strategy has the highest chance of winning (code provided for you below).
# - To do this, build a function to determine the probability of winning for each of the three strategies.
# Note if you do not use numpy, this next step will take a long time.

# %%
swap_behav = {0:"always_trade", 1:"never_trade", 2: 'randomly_trade'}


def simulate_with_strategy( swap_behavior = 0,   num_doors=3, num_doors_to_open=1 ,N=10000):
    raise(NotImplementedError)

# Don't touch the rest of this cell unless you know what you are doing
strategy_map = {0: "Always Trade", 1: "Never Trade", 2: "Randomly Trade"}

def evaluate_strategy(num_doors=3, num_doors_to_open=1 ,N=10000):
    success = { }
    for i in range(3):
        success[ strategy_map[i]] = simulate_with_strategy(swap_behavior=i,
                                           num_doors=num_doors, num_doors_to_open=num_doors_to_open, N=N)
           
    df = pd.DataFrame.from_dict( success, orient='index')
    # results 
    df.plot.bar()
    plt.title("Probability of Success with " + str(num_doors)+ " doors and " + str(num_doors_to_open) + " doors opened" )
    plt.xlabel("Strategy")
    plt.ylabel("Success")
    title = "doors_"+str(num_doors) + "_opened_" + str(num_doors_to_open)
    plt.savefig( title +'.png', bbox_inches='tight')
    plt.show()

# %%
print("*" * 100)
# Out:
# ****************************************************************************************************

# %% [markdown]
# # Problem 12
# Use your solution to the previous problem to determine what happens as the number of doors is large (say 1000) and the number of doors opened is small (say 1)
# - Use N=1000
#
# Warning: This will take a minute or so to run!

# %%
# Solution
# What happens when n doors gets large, and num doors to open is also large?
# P(S)--> 1
evaluate_strategy(num_doors=1000, num_doors_to_open=998,N=1000)

# %%
print("*" * 100)
# Out:
# ****************************************************************************************************
